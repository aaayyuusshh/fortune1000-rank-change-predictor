# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## Adding numerical column to input & improving our Tensorflow model from Part 3
# (copy pasting the old model file here and making changes)

# %% [markdown]
# ## Dividing data into train data and test data
#     - train data & test data will be in the form of numpy arrays
#     - train data: x_train, y_train
#     - test data: x_test, y_test
#     - x portion is the input var, y portion is the output var

# %%
# loading our clean dataset
df = pd.read_csv("data-cleaned.csv")

# %%
# configuring sizes of our train & test dataframes
dfSize = len(df)
trainSize = int(dfSize * 0.6)
testSize = int(dfSize * 0.4)


# grabbing our training dataframes (adding numerical column "profited")
x_train_df = df[["revenues", "revenue_percent_change", "profits", 
                "profits_percent_change", "assets", "market_value", "employees", "profited"]].head(trainSize)
y_train_df = df["rank_change"].head(trainSize)

x_train_df["profited"] = x_train_df["profited"].replace(True, 1);
x_train_df["profited"] = x_train_df["profited"].replace(False, 0);

# converting our training dataframes to numpy arrays
x_train = np.array(x_train_df)
y_train = np.array(y_train_df)

#grabbing our testing dataframes
x_test_df = df[["revenues", "revenue_percent_change", "profits", 
                "profits_percent_change", "assets", "market_value", "employees", "profited"]].tail(testSize)
y_test_df = df["rank_change"].tail(testSize)

x_test_df["profited"] = x_test_df["profited"].replace(True, 1);
x_test_df["profited"] = x_test_df["profited"].replace(False, 0);

#converting our testing dataframes to numpy arrays
x_test = np.array(x_test_df)
y_test = np.array(y_test_df)

# %%
# verifying the lengths of our training & testing numpy arrays
print(len(x_train) == trainSize & len(y_train) == trainSize)
print(len(x_test) == testSize & len(y_test) == testSize)
# Out:
# True
# True

# %% [markdown]
# ## Building our model : Improvement done here

# %% [markdown]
# ### Goal: Predit if the company rank changed from previous year or not based on 6 input vars
#     - input vars: "revenues", "revenue_percent_change", "profits", "profits_percent_change", "assets", "employees", "profitted"
#
# ### Changes made to tackle overfitting
# - Added Dropout to the 2 hidden layers at rate 0.8
# - Reduced epoch 200 from 1000 to reduce complexity
# - This prevents model from overfitting
#     - Before -> Big delta between train and test accuracy, favouring the training data.
#     - After -> Train Accuracy: 73.3%, Test Accuracy: 68.4%

# %%
# normalize the dataset
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# build the model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation = tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.8))
model.add(tf.keras.layers.Dense(128, activation = tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.8))
model.add(tf.keras.layers.Dense(1, activation = tf.nn.sigmoid))

model.compile(tf.keras.optimizers.Adam(learning_rate=0.001), loss = "binary_crossentropy", metrics = ["accuracy"])

# train the model with trainig data
model.fit(x_train, y_train, epochs = 200)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7039 - accuracy: 0.5437
# Epoch 2/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.5534
# Epoch 3/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6715 - accuracy: 0.5995
# Epoch 4/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6594 - accuracy: 0.6456
# Epoch 5/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6664 - accuracy: 0.6238
# Epoch 6/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6480 - accuracy: 0.6529
# Epoch 7/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6707 - accuracy: 0.6335
# Epoch 8/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6464 - accuracy: 0.6383
# Epoch 9/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6579 - accuracy: 0.6311
# Epoch 10/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6651 - accuracy: 0.6578
# Epoch 11/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6503 - accuracy: 0.6408
# Epoch 12/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6615 - accuracy: 0.6359
# Epoch 13/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6545 - accuracy: 0.6432
# Epoch 14/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6441 - accuracy: 0.6408
# Epoch 15/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6387 - accuracy: 0.6529
# Epoch 16/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6370 - accuracy: 0.6432
# Epoch 17/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6276 - accuracy: 0.6650
# Epoch 18/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6361 - accuracy: 0.6505
# Epoch 19/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6360 - accuracy: 0.6481
# Epoch 20/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6295 - accuracy: 0.6626
# Epoch 21/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6309 - accuracy: 0.6699
# Epoch 22/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6448 - accuracy: 0.6626
# Epoch 23/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6352 - accuracy: 0.6578
# Epoch 24/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6303 - accuracy: 0.6748
# Epoch 25/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6255 - accuracy: 0.6529
# Epoch 26/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6121 - accuracy: 0.6723
# Epoch 27/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6118 - accuracy: 0.6723
# Epoch 28/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6348 - accuracy: 0.6699
# Epoch 29/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6124 - accuracy: 0.6675
# Epoch 30/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6189 - accuracy: 0.6796
# Epoch 31/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6237 - accuracy: 0.6553
# Epoch 32/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6190 - accuracy: 0.6723
# Epoch 33/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6150 - accuracy: 0.6796
# Epoch 34/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6032 - accuracy: 0.7015
# Epoch 35/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6208 - accuracy: 0.6893
# Epoch 36/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6183 - accuracy: 0.6650
# Epoch 37/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6212 - accuracy: 0.6917
# Epoch 38/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6175 - accuracy: 0.6578
# Epoch 39/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6152 - accuracy: 0.6748
# Epoch 40/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6335 - accuracy: 0.6650
# Epoch 41/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6042 - accuracy: 0.7184
# Epoch 42/200
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6128 - accuracy: 0.6723
# Epoch 43/200
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6329 - accuracy: 0.6723
# Epoch 44/200
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6024 - accuracy: 0.6869
# Epoch 45/200
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6281 - accuracy: 0.6796
# Epoch 46/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6136 - accuracy: 0.6772
# Epoch 47/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6012 - accuracy: 0.6796
# Epoch 48/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6166 - accuracy: 0.6772
# Epoch 49/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6189 - accuracy: 0.6796
# Epoch 50/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5929 - accuracy: 0.6869
# Epoch 51/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6079 - accuracy: 0.6820
# Epoch 52/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6247 - accuracy: 0.6796
# Epoch 53/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6018 - accuracy: 0.6942
# Epoch 54/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6001 - accuracy: 0.7112
# Epoch 55/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6077 - accuracy: 0.6772
# Epoch 56/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6123 - accuracy: 0.6917
# Epoch 57/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6133 - accuracy: 0.6772
# Epoch 58/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.6893
# Epoch 59/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5951 - accuracy: 0.7112
# Epoch 60/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6172 - accuracy: 0.6796
# Epoch 61/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6076 - accuracy: 0.6917
# Epoch 62/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6012 - accuracy: 0.6893
# Epoch 63/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6116 - accuracy: 0.6796
# Epoch 64/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6182 - accuracy: 0.6723
# Epoch 65/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5968 - accuracy: 0.6869
# Epoch 66/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6081 - accuracy: 0.6675
# Epoch 67/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5983 - accuracy: 0.6796
# Epoch 68/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6067 - accuracy: 0.6772
# Epoch 69/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6017 - accuracy: 0.6796
# Epoch 70/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6018 - accuracy: 0.6820
# Epoch 71/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5903 - accuracy: 0.7015
# Epoch 72/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5848 - accuracy: 0.7112
# Epoch 73/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5981 - accuracy: 0.6942
# Epoch 74/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5969 - accuracy: 0.6917
# Epoch 75/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6065 - accuracy: 0.6893
# Epoch 76/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5750 - accuracy: 0.7184
# Epoch 77/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6037 - accuracy: 0.7136
# Epoch 78/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5986 - accuracy: 0.7087
# Epoch 79/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5873 - accuracy: 0.7112
# Epoch 80/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6034 - accuracy: 0.6942
# Epoch 81/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5927 - accuracy: 0.6917
# Epoch 82/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.7063
# Epoch 83/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6066 - accuracy: 0.6869
# Epoch 84/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6010 - accuracy: 0.6820
# Epoch 85/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5998 - accuracy: 0.7039
# Epoch 86/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5935 - accuracy: 0.6966
# Epoch 87/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5982 - accuracy: 0.6917
# Epoch 88/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6039 - accuracy: 0.6917
# Epoch 89/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6015 - accuracy: 0.7015
# Epoch 90/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5876 - accuracy: 0.7136
# Epoch 91/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5915 - accuracy: 0.6966
# Epoch 92/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5989 - accuracy: 0.6796
# Epoch 93/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6038 - accuracy: 0.7039
# Epoch 94/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6121 - accuracy: 0.6966
# Epoch 95/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6111 - accuracy: 0.6820
# Epoch 96/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6079 - accuracy: 0.6917
# Epoch 97/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5945 - accuracy: 0.6772
# Epoch 98/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5911 - accuracy: 0.6966
# Epoch 99/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5985 - accuracy: 0.6917
# Epoch 100/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5992 - accuracy: 0.6990
# Epoch 101/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5875 - accuracy: 0.7160
# Epoch 102/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5948 - accuracy: 0.7039
# Epoch 103/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.7039
# Epoch 104/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5923 - accuracy: 0.7063
# Epoch 105/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6029 - accuracy: 0.6820
# Epoch 106/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5891 - accuracy: 0.7209
# Epoch 107/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5935 - accuracy: 0.6966
# Epoch 108/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5807 - accuracy: 0.7136
# Epoch 109/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5952 - accuracy: 0.7015
# Epoch 110/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5789 - accuracy: 0.7184
# Epoch 111/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5760 - accuracy: 0.7087
# Epoch 112/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5975 - accuracy: 0.7160
# Epoch 113/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5867 - accuracy: 0.7063
# Epoch 114/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5882 - accuracy: 0.7087
# Epoch 115/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5844 - accuracy: 0.7087
# Epoch 116/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5784 - accuracy: 0.7087
# Epoch 117/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5878 - accuracy: 0.6917
# Epoch 118/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5829 - accuracy: 0.7015
# Epoch 119/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5731 - accuracy: 0.7087
# Epoch 120/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5900 - accuracy: 0.6990
# Epoch 121/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5966 - accuracy: 0.6966
# Epoch 122/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5843 - accuracy: 0.7160
# Epoch 123/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5884 - accuracy: 0.7087
# Epoch 124/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5921 - accuracy: 0.7039
# Epoch 125/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5885 - accuracy: 0.7087
# Epoch 126/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5807 - accuracy: 0.7063
# Epoch 127/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5947 - accuracy: 0.6990
# Epoch 128/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5952 - accuracy: 0.7087
# Epoch 129/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5836 - accuracy: 0.7015
# Epoch 130/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6092 - accuracy: 0.6869
# Epoch 131/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5849 - accuracy: 0.7233
# Epoch 132/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5887 - accuracy: 0.7015
# Epoch 133/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5752 - accuracy: 0.7039
# Epoch 134/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5825 - accuracy: 0.7112
# Epoch 135/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5909 - accuracy: 0.7112
# Epoch 136/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5766 - accuracy: 0.7160
# Epoch 137/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6037 - accuracy: 0.7039
# Epoch 138/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6138 - accuracy: 0.7112
# Epoch 139/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5793 - accuracy: 0.7160
# Epoch 140/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5954 - accuracy: 0.7112
# Epoch 141/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5845 - accuracy: 0.7160
# Epoch 142/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5759 - accuracy: 0.7063
# Epoch 143/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5887 - accuracy: 0.7233
# Epoch 144/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5964 - accuracy: 0.6990
# Epoch 145/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5895 - accuracy: 0.7160
# Epoch 146/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5976 - accuracy: 0.6942
# Epoch 147/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5913 - accuracy: 0.7136
# Epoch 148/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5707 - accuracy: 0.7209
# Epoch 149/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5863 - accuracy: 0.7184
# Epoch 150/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5669 - accuracy: 0.7209
# Epoch 151/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5909 - accuracy: 0.7112
# Epoch 152/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5807 - accuracy: 0.7160
# Epoch 153/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6084 - accuracy: 0.6820
# Epoch 154/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5925 - accuracy: 0.7039
# Epoch 155/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5856 - accuracy: 0.6942
# Epoch 156/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.7112
# Epoch 157/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5866 - accuracy: 0.7112
# Epoch 158/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5911 - accuracy: 0.7112
# Epoch 159/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5858 - accuracy: 0.7039
# Epoch 160/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5845 - accuracy: 0.7160
# Epoch 161/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5721 - accuracy: 0.7257
# Epoch 162/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5900 - accuracy: 0.6942
# Epoch 163/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5911 - accuracy: 0.7184
# Epoch 164/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5716 - accuracy: 0.7257
# Epoch 165/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5944 - accuracy: 0.7160
# Epoch 166/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5959 - accuracy: 0.7063
# Epoch 167/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5724 - accuracy: 0.7257
# Epoch 168/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5988 - accuracy: 0.7015
# Epoch 169/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5937 - accuracy: 0.7233
# Epoch 170/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5732 - accuracy: 0.7233
# Epoch 171/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5918 - accuracy: 0.6942
# Epoch 172/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5612 - accuracy: 0.7282
# Epoch 173/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5820 - accuracy: 0.6966
# Epoch 174/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5741 - accuracy: 0.7015
# Epoch 175/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5658 - accuracy: 0.7112
# Epoch 176/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5911 - accuracy: 0.7136
# Epoch 177/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5853 - accuracy: 0.7136
# Epoch 178/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5833 - accuracy: 0.7112
# Epoch 179/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5785 - accuracy: 0.7087
# Epoch 180/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5693 - accuracy: 0.7039
# Epoch 181/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5898 - accuracy: 0.7087
# Epoch 182/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5911 - accuracy: 0.6966
# Epoch 183/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5767 - accuracy: 0.7015
# Epoch 184/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5754 - accuracy: 0.7257
# Epoch 185/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5614 - accuracy: 0.7330
# Epoch 186/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5708 - accuracy: 0.7112
# Epoch 187/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5916 - accuracy: 0.7087
# Epoch 188/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5834 - accuracy: 0.6942
# Epoch 189/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.7087
# Epoch 190/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5589 - accuracy: 0.7306
# Epoch 191/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5734 - accuracy: 0.6966
# Epoch 192/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5913 - accuracy: 0.7039
# Epoch 193/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5676 - accuracy: 0.7160
# Epoch 194/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5936 - accuracy: 0.7063
# Epoch 195/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5808 - accuracy: 0.7015
# Epoch 196/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5874 - accuracy: 0.7209
# Epoch 197/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5737 - accuracy: 0.7306
# Epoch 198/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5731 - accuracy: 0.7063
# Epoch 199/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5695 - accuracy: 0.7233
# Epoch 200/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5641 - accuracy: 0.7039

# %% [markdown]
# ## Evaluating model

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
# Out:
# --Evaluate model--
# 13/13 - 0s - loss: 0.5567 - accuracy: 0.7330 - 120ms/epoch - 9ms/step
# 9/9 - 0s - loss: 0.6256 - accuracy: 0.6836 - 23ms/epoch - 3ms/step
# Train / Test Accuracy: 73.3% / 68.4%
